# %% [markdown]
# # NYC Taxi Trip Duration EDA
#
# Use this notebook for exploratory analysis only. Production preprocessing, feature engineering, training, and evaluation live in `src/taxi_duration/`.

# %%
from pathlib import Path
import pandas as pd

path = Path('../data/raw/yellow_tripdata_2024-01.parquet')
df = pd.read_parquet(path)
df.head()

# %%
df.info()

# %%
duration = (pd.to_datetime(df['tpep_dropoff_datetime']) - pd.to_datetime(df['tpep_pickup_datetime'])).dt.total_seconds() / 60
duration.describe(percentiles=[0.01, 0.05, 0.5, 0.95, 0.99])
